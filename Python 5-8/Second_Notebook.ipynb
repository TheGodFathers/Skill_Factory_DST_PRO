# %%
import pandas as pd

data = pd.Series(["Январь", "Февраль", "Март", "Апрель"],
                 index = ['Первый', "Второй", "Третий", "Четвёртый"])

# %%
for i,k in data.items():
    print(i,k)
# Out:
# Первый Январь
# Второй Февраль
# Третий Март
# Четвёртый Апрель

# %%
data.loc [['Первый' : 'Третий']]
# Out:
#   File "<ipython-input-29-5a14baaffc8c>", line 1
#     data.loc [['Первый' : 'Третий']]
#                         ^
# SyntaxError: invalid syntax

# %%
data[0:2]
# Out:
# Первый     Январь
# Второй    Февраль
# dtype: object

# %%
data = pd.Series(list(range(10, 1001))) 
data[990]
# Out:
# 1000

# %%
df = pd.DataFrame({'col1': [1, 2], 'col2': [3, 4]})
display(df)
# Out:
#    col1  col2
# 0     1     3
# 1     2     4

# %%
pd.DataFrame({'Тестовая колонка':[1,5]})
# Out:
#    Тестовая колонка
# 0                 1
# 1                 5

# %%
for i in range (100):
    pd.DataFrame({'Тестовая колонка':[i, i+i**2]})
# Out:
#    Тестовая колонка
# 0                99
# 1              9900

# %%
import pandas as pd
football = pd.read_csv('data_sf.xls')
a = football[football.Value > football.Value.mean()].Nationality
countries = {}
c = 0
for i in a:
    info = i.split(' ')
    country = info[0]
    if country not in countries:
        countries.setdefault(country,1 )
    elif country in countries:
        countries[country] += 1
import operator
max(countries.items(), key=operator.itemgetter(1))[0]
# Out:
# 'Spain'

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(football.describe())
# Out:
#          Unnamed: 0           Age         Value           Wage      Crossing  \
# count  12897.000000  12897.000000  1.289700e+04   12897.000000  12897.000000
# mean    6605.040862     24.795379  2.112449e+06    7517.562224     47.076374
# std     3782.545526      4.872212  6.498424e+06   23061.985387     18.043470
# min        0.000000     16.000000  0.000000e+00    1000.000000      5.000000
# 25%     3357.000000     21.000000  2.500000e+05    1000.000000     35.000000
# 50%     6622.000000     24.000000  5.000000e+05    2000.000000     51.000000
# 75%     9876.000000     28.000000  8.500000e+05    4000.000000     61.000000
# max    13125.000000     45.000000  1.185000e+08  565000.000000     93.000000
#
#           Finishing  HeadingAccuracy  ShortPassing       Volleys  \
# count  12897.000000     12897.000000  12897.000000  12897.000000
# mean      42.876328        50.202528     56.026983     40.295030
# std       19.096935        17.281593     14.740436     17.080687
# ...

# %%
df = pd.DataFrame([[i,i+1.2,i+2, 'hi'] for i in range(10)],
                  columns = ['foo', 'bar', 'baz', 'foobar'])

# %%
df.mean()
# Out:
# foo    4.5
# bar    5.7
# baz    6.5
# dtype: float64

# %%
import pandas as pd
football = pd.read_csv('data_sf.xls')
football[(football.Aggression == football.Aggression.max())].ShotPower.mean() / football[(football.Aggression == football.Aggression.min())].ShotPower.mean()
# Out:
# 2.076923076923077

# %%
small_df = football
#display(football)
s = small_df['FKAccuracy'].value_counts(bins = 5)
s
# Out:
# (21.2, 39.4]     4859
# (39.4, 57.6]     3957
# (57.6, 75.8]     2108
# (2.908, 21.2]    1760
# (75.8, 94.0]      213
# Name: FKAccuracy, dtype: int64

# %%
small_df = football[football.columns[0:7]].head(25)
s = small_df['Wage'].value_counts(bins=4)
display(s)
s.index
s.index[3]
s.index[3].left
# Out:
# (211750.0, 329500.0]     9
# (93528.999, 211750.0]    8
# (329500.0, 447250.0]     6
# (447250.0, 565000.0]     2
# Name: Wage, dtype: int64
# 447250.0

# %%
small_df.loc[(small_df['Wage'] > s.index[3].left) & (small_df['Wage'] <= s.index[3].right)]
# Out:
#    Unnamed: 0       Name  Age Nationality          Club      Value    Wage
# 0           0   L. Messi   31   Argentina  FC Barcelona  110500000  565000
# 7           7  L. Suárez   31     Uruguay  FC Barcelona   80000000  455000

# %%
import pandas as pd
import numpy as np
a=pd.read_csv('data_sf.xls')
spain_p = a[a['Nationality'] == 'Spain'] a[a['Age'] == 21].value_counts(normalize = True)
display(spain_p)
# Out:
#   File "<ipython-input-170-503e82cbc35e>", line 4
#     spain_p = a[a['Nationality'] == 'Spain'] a[a['Age'] == 21].value_counts(normalize = True)
#                                              ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import numpy as np
a=pd.read_csv('data_sf.xls')
s =round(a[a['Nationality']=='Spain']['Age'].value_counts(normalize=True)*100,2)
s
# Out:
# 21    11.77
# 22     9.54
# 20     7.75
# 23     7.15
# 25     6.41
# 27     6.26
# 24     5.96
# 28     5.37
# 26     5.37
# 29     4.77
# 19     4.77
# 18     3.87
# 30     3.87
# 31     3.28
# 32     3.28
# 33     3.13
# 34     2.24
# 17     1.34
# 35     1.19
# 36     1.04
# 37     0.89
# 39     0.30
# 16     0.30
# 38     0.15
# Name: Age, dtype: float64

# %%
a_grouped = a.groupby(['Position'])['Wage'].sum().sort_values(ascending = False) > 5000000
display(a_grouped)
#a_grouped.loc['Juventus']['Wage']
# Out:
# Position
# ST      True
# GK      True
# CB      True
# CM      True
# LB      True
# CAM     True
# LM      True
# RM      True
# RB      True
# CDM    False
# RCB    False
# LCB    False
# RW     False
# RCM    False
# LCM    False
# LW     False
# LS     False
# RDM    False
# RS     False
# LDM    False
# RF     False
# LF     False
# RWB    False
# LAM    False
# LWB    False
# CF     False
# RAM    False
# Name: Wage, dtype: bool

# %%
a.groupby(['Nationality'])[['Wage','Age','ShotPower']].mean().sort_values(['Wage'],ascending = False).head(10)
# Out:
#                             Wage        Age  ShotPower
# Nationality
# Dominican Republic  71000.000000  23.000000  75.500000
# Egypt               35545.454545  25.818182  59.363636
# Gabon               28900.000000  26.400000  56.900000
# Croatia             26722.222222  24.819444  54.305556
# Equatorial Guinea   25666.666667  28.000000  55.333333
# Belgium             20024.390244  24.030488  56.390244
# Ecuador             18333.333333  24.619048  60.666667
# Uruguay             17590.361446  26.771084  56.192771
# Brazil              17371.158392  27.898345  58.203310
# Algeria             15810.810811  27.027027  56.567568

# %%
a.loc[a['Nationality'] == 'Dominican Republic'][['Name','Age', 'Wage']]
# Out:
#             Name  Age    Wage
# 291      Mariano   24  140000
# 6279  L. Quezada   22    2000

# %%
a.groupby(['Position'])[['Wage','Value']].mean().sort_values(['Value'],ascending = False)
# Out:
#                    Wage         Value
# Position
# LF         75125.000000  2.736250e+07
# RF        119000.000000  2.636583e+07
# LAM        61000.000000  1.324583e+07
# RAM        11800.000000  8.345000e+06
# LS         15421.487603  5.848430e+06
# LCM        13497.854077  4.318090e+06
# RCM        13504.166667  4.217604e+06
# RS         13482.456140  3.645833e+06
# LW         12169.421488  3.603099e+06
# RW         13822.784810  3.495738e+06
# LDM        10243.243243  3.369459e+06
# RCB        11270.334928  3.009055e+06
# CAM         8688.783570  2.963199e+06
# RDM        11282.608696  2.692717e+06
# LCB         9753.056235  2.636516e+06
# LM          7472.527473  2.466174e+06
# ST          7852.513228  2.157252e+06
# RM          6655.352480  2.138734e+06
# LWB         5783.333333  1.931333e+06
# CF          4862.745098  1.848627e+06
# CDM         7121.562952  1.658900e+06
# CM          5805.060918  1.617465e+06
# RWB         6000.000000  1.555571e+06
# ...

# %%
a.groupby(['Club'])[['Name']].count()
# Out:
#                        Name
# Club
#  SSV Jahn Regensburg     24
# 1. FC Heidenheim 1846    20
# 1. FC Kaiserslautern     23
# 1. FC Köln               10
# 1. FC Magdeburg          21
# ...                     ...
# Zagłębie Sosnowiec       25
# Çaykur Rizespor          22
# Örebro SK                26
# Östersunds FK            20
# Śląsk Wrocław            24
#
# [650 rows x 1 columns]

# %%
a.groupby(['Club'])[['Strength','Name']].max()
# Out:
#                        Strength         Name
# Club
#  SSV Jahn Regensburg         92    S. Stolze
# 1. FC Heidenheim 1846        86    V. Eicher
# 1. FC Kaiserslautern         85      W. Hesl
# 1. FC Köln                   76   Y. Bisseck
# 1. FC Magdeburg              86    T. Müller
# ...                         ...          ...
# Zagłębie Sosnowiec           84  Z. Udovičić
# Çaykur Rizespor              81       S. Koç
# Örebro SK                    85  V. Tranberg
# Östersunds FK                88     T. Tekie
# Śląsk Wrocław                85     W. Golla
#
# [650 rows x 2 columns]

# %%
b = a[a['Club'] == 'FC Barcelona']
c = b[a['Nationality'] == 'Argentina']
#display(b)
display(c.groupby(['Nationality'])['Strength'].max())
c.groupby(['Nationality'])['Balance'].max()
# Out:
# <ipython-input-311-0a8cb93eade5>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c = b[a['Nationality'] == 'Argentina']
# Nationality
# Argentina    59
# Name: Strength, dtype: int64
# Nationality
# Argentina    95
# Name: Balance, dtype: int64

# %%
pivot = a.loc[a['Club'].isin(['FC Barcelona','Real Madrid','Juventus','Manchester United'])].pivot_table(values=['Wage'],
index=['Nationality'],
columns=['Club'],
aggfunc='sum',
margins=True,
fill_value = 0)
#display(pivot)

# %%
df2 = a.pivot_table(columns = 'Position', index = 'Club', values = 'Wage', aggfunc = 'max')
df2.loc['Manchester City']['GK']
# Out:
# 125000.0

# %%
pivot = a.pivot_table(
values='Name',
index='Club',
columns='Position',
aggfunc='count',
fill_value = 0
)
display(pivot)
round(pivot['GK'].mean(),3)
# Out:
# Position               CAM  CB  CDM  CF  CM  GK  LAM  LB  LCB  LCM  ...  RB  \
# Club                                                                ...
#  SSV Jahn Regensburg     0   5    1   0   2   3    0   2    0    0  ...   2
# 1. FC Heidenheim 1846    1   3    0   0   1   2    0   2    1    0  ...   2
# 1. FC Kaiserslautern     0   3    3   0   0   3    0   2    1    0  ...   2
# 1. FC Köln               0   1    1   0   2   3    0   0    0    0  ...   1
# 1. FC Magdeburg          0   4    0   1   0   3    0   1    1    1  ...   0
# ...                    ...  ..  ...  ..  ..  ..  ...  ..  ...  ...  ...  ..
# Zagłębie Sosnowiec       3   2    2   0   0   3    0   3    1    0  ...   1
# Çaykur Rizespor          1   2    5   0   0   3    0   2    1    0  ...   3
# Örebro SK                0   4    0   0   1   3    0   0    1    1  ...   0
# Östersunds FK            1   1    0   1   3   3    0   2    1    1  ...   1
# ...

# %%
df = a
pivot = df.pivot_table(index=['Club'], values=['Name'],
                       columns=['Position'],
                       aggfunc='count',
                       fill_value=0)
pivot_df=pivot.reset_index()
s = pivot_df['Name']['CM'].value_counts()
s_df = s.reset_index()
s_df.columns = ['number', 'clubs']
display(s_df)
# Out:
#    number  clubs
# 0       1    211
# 1       2    149
# 2       0    136
# 3       3     89
# 4       4     39
# 5       5     21
# 6       6      5

# %%
# Out:
#        Unnamed: 0                Name  Age Nationality                 Club  \
# 0               0            L. Messi   31   Argentina         FC Barcelona
# 1               1   Cristiano Ronaldo   33    Portugal             Juventus
# 2               2           Neymar Jr   26      Brazil  Paris Saint-Germain
# 3               3              De Gea   27       Spain    Manchester United
# 4               4        K. De Bruyne   27     Belgium      Manchester City
# ...           ...                 ...  ...         ...                  ...
# 12892       13121        J. Lundstram   19     England      Crewe Alexandra
# 12893       13122  N. Christoffersson   19      Sweden       Trelleborgs FF
# 12894       13123           B. Worman   16     England     Cambridge United
# 12895       13124      D. Walker-Rice   17     England      Tranmere Rovers
# 12896       13125           G. Nugent   16     England      Tranmere Rovers
#
# ...

# %%
df = a
a_st = a[a['Position'] == 'ST']
pivot = a_st.pivot_table(index='Position',
                       values='SprintSpeed',
                       columns='Club',
                       aggfunc = 'mean',
                       fill_value = 0)
pivot.sort_values(by = 'ST', axis = 1,ascending = False)
# Out:
# Club      Vitória  Sydney FC  CD Lugo  Brøndby IF  Leicester City  \
# Position
# ST             91         88       87   84.666667            84.5
#
# Club      Manchester United  Feyenoord  KRC Genk  FC Bayern München  \
# Position
# ST                       84         84        84                 84
#
# Club      FC Zürich  ...  Club Atlético Tigre  Chievo Verona  \
# Position             ...
# ST               84  ...                 49.5           49.5
#
# Club      Estudiantes de La Plata  Çaykur Rizespor  Beijing Renhe FC  \
# Position
# ST                             49               48              47.5
#
# Club      SV Darmstadt 98  Real Sociedad  San Jose Earthquakes  \
# Position
# ST                   47.5             46                    45
#
# Club      1. FC Magdeburg  Club Tijuana
# Position
# ST                     44            40
#
# [1 rows x 591 columns]

# %%
df = a.groupby(['Club']).groups
df['Ajax']
# Out:
# Int64Index([152, 188, 234, 300, 319, 352, 737, 1335, 3111, 3769, 4847, 4897,
#             5010],
#            dtype='int64')
